# %% [markdown]
# # Evaluating Models on FS-Mol
#
# `fs_mol.utils.test_utils.eval_model()` is a utility function that allows to evaluate a model against the full set of FS-Mol testing tasks, following a fixed evaluation scheme.
#
# It requires the following arguments:
# * `test_model_fn: Callable[[FSMolTaskSample, str, int], BinaryEvalMetrics]`:
#   This is the core evaluation function, taking a `FSMolTaskSample` (that is, a sample of datapoints from a single task -- see notebooks/dataset.ipynb), a temporary output folder in which to store scratch data, and the seed used for the sampling.
#   It should return `BinaryEvalMetric` object containing all metrics calculated from the model output and labels of the task sample.
# * `dataset: FSMolDataset`:
#   The actual dataset, which can be the full FS-Mol dataset as released, or a different set created directly through its constructor.
#   This is particularly useful if you are planning to evaluate models on a set of tasks differing from FS-Mol's test set.
#
# The returned results contain a list of evaluation metrics for each task, in a dictionary indexed by task name.
#
# Additionally, it can be optionally further configured using the following optional arguments:
# * `out_dir: Optional[str]`:
#    If provided, a summary of the evaluation results will be written, as one CSV file per task.
# * `seed: int`:
#    A seed value used to make sampling and splitting of tasks deterministic.
#    If set to anything but `0`, results of `eval_model` will be incomparable to the canonical evaluation runs.
# * `num_samples: int`:
#    The number of random splits to draw for the task undergoing evaluation.
# * `train_set_sample_sizes: List[int]`:
#    The sizes of training / support set data to consider. For each of these, `num_samples` samples will be drawn for each test task, and then be used to call `test_model_fn` with, where the passed `FSMolTaskSample` will have the requested number of `train_samples`.
# * `valid_size_or_ratio: Union[int, float]`:
#    Number or ratio of `train_samples` in the drawn samples that will be split out into `validation_samples`. This is useful for models that require an explicit validation set during fine-tuning.
# * `test_size_or_ratio: Optional[Union[int, float, Tuple[int, int]]]`:
#    Number or ratio of `test_samples` that will be drawn from the original task. By default, all available samples will be used, but it may be useful to limit this when not using `eval_model` for full model evaluation.
# * `fold: DataFold`:
#    The fold of FS-Mol on which to perform evaluation, typically will be the test fold.
# * `task_reader_fn: Optional[Callable[[List[RichPath], int], Iterable[FSMolTask]]]`:
#    Callable allowing additional transformations on the data prior to its batching and passing through a model.

# %% [markdown]
# ## Example: Evaluating a Random Forest Model

# %%
# Setting up local details:
import os
import sys

# This should be the location of the checkout of the FS-Mol repository:
FS_MOL_CHECKOUT_PATH = os.path.join("/data/local/apps/", "Meta-Learning", "FS-Mol")
FS_MOL_DATASET_PATH = os.path.join("/data/local/apps/", "Meta-Learning", "FS-Mol", "datasets")

os.chdir(FS_MOL_CHECKOUT_PATH)
sys.path.insert(0, FS_MOL_CHECKOUT_PATH)

# %% [markdown]
# We first define a simple implementation of a `test_model_fn` that creates a random forest model, using the scikit-learn default implementation and parameters.

# %%
import numpy as np
from sklearn.ensemble import RandomForestClassifier

from fs_mol.data.fsmol_task import FSMolTaskSample
from fs_mol.utils.metrics import BinaryEvalMetrics, compute_binary_task_metrics

def test_model_fn(
    task_sample: FSMolTaskSample, temp_out_folder: str, seed: int
) -> BinaryEvalMetrics:
    train_data = task_sample.train_samples
    test_data = task_sample.test_samples

    # get data in to form for sklearn
    X_train = np.array([x.get_fingerprint() for x in train_data])
    X_test = np.array([x.get_fingerprint() for x in test_data])
    y_train = [float(x.bool_label) for x in train_data]
    y_test = [float(x.bool_label) for x in test_data]

    model = RandomForestClassifier()
    model.fit(X_train, y_train)

    # Compute test results:
    y_predicted_true_probs = model.predict_proba(X_test)[:, 1]
    test_metrics = compute_binary_task_metrics(y_predicted_true_probs, y_test)

    return test_metrics

# %% [markdown]
# Given these functions, we can now evaluate these models on the test tasks in FS-Mol as follows, reducing the space of considered samples from each task for speed purposes:

# %%
from fs_mol.data.fsmol_dataset import FSMolDataset, DataFold
from fs_mol.utils.test_utils import eval_model

fsmol_dataset = FSMolDataset.from_directory(FS_MOL_DATASET_PATH)

results = eval_model(
    test_model_fn=test_model_fn,
    dataset=fsmol_dataset,
    # Restrict number of samples to one per task:
    train_set_sample_sizes=[16],
    num_samples=1,
)

results
# Out:
# {'CHEMBL1066254': [FSMolTaskSampleEvalResults(size=125, acc=0.688, balanced_acc=0.6918545081967213, f1=0.7272727272727272, prec=0.6341463414634146, recall=0.8524590163934426, roc_auc=0.7792008196721312, avg_precision=0.7488349885286565, kappa=0.38063778427137596, task_name='CHEMBL1066254', seed=0, num_train=16, num_test=125, fraction_pos_train=0.5, fraction_pos_test=0.488)],
#  'CHEMBL1006005': [FSMolTaskSampleEvalResults(size=171, acc=0.543859649122807, balanced_acc=0.5472085385878489, f1=0.613861386138614, prec=0.5254237288135594, recall=0.7380952380952381, roc_auc=0.612616310892173, avg_precision=0.5721912243861041, kappa=0.0937627395026498, task_name='CHEMBL1006005', seed=0, num_train=16, num_test=171, fraction_pos_train=0.5, fraction_pos_test=0.49122807017543857)],
#  'CHEMBL1243967': [FSMolTaskSampleEvalResults(size=192, acc=0.6666666666666666, balanced_acc=0.6666666666666667, f1=0.7217391304347827, prec=0.6194029850746269, recall=0.8645833333333334, roc_auc=0.7210286458333334, avg_precision=0.6762134023728347, kappa=0.33333333333333337, task_name='CHEMBL1243967', seed=0, num_train=16, num_test=192, fraction_pos_train=0.5, fraction_pos_test=0.5)],
#  'CHEMBL1613926': [FSMolTaskSampleEvalResults(size=119, acc=0.6470588235294118, balanced_acc=0.647316384180791, f1=0.6557377049180327, prec=0.6349206349206349, recall=0.6779661016949152, roc_auc=0.6607344632768362, avg_precision=0.5639302819672257, kappa=0.2944664031620553, task_name='CHEMBL1613926', seed=0, num_train=16, num_test=119, fraction_pos_train=0.5, fraction_pos_test=0.4957983193277311)],
#  'CHEMBL1613949': [FSMolTaskSampleEvalResults(size=142, acc=0.6619718309859155, balanced_acc=0.5102040816326531, f1=0.039999999999999994, prec=1.0, recall=0.02040816326530612, roc_auc=0.5299539170506913, avg_precision=0.4333447256379696, kappa=0.0265638389031706, task_name='CHEMBL1613949', seed=0, num_train=16, num_test=142, fraction_pos_train=0.3125, fraction_pos_test=0.34507042253521125)],
#  'CHEMBL1613907': [FSMolTaskSampleEvalResults(size=133, acc=0.5338345864661654, balanced_acc=0.5397058823529413, f1=0.6265060240963856, prec=0.5148514851485149, recall=0.8, roc_auc=0.5918552036199095, avg_precision=0.5661154475696202, kappa=0.07845328565042475, task_name='CHEMBL1613907', seed=0, num_train=16, num_test=133, fraction_pos_train=0.5, fraction_pos_test=0.48872180451127817)],
#  'CHEMBL1243970': [FSMolTaskSampleEvalResults(size=192, acc=0.6458333333333334, balanced_acc=0.6458333333333334, f1=0.6964285714285714, prec=0.609375, recall=0.8125, roc_auc=0.7028537326388891, avg_precision=0.6908115770193924, kappa=0.29166666666666663, task_name='CHEMBL1243970', seed=0, num_train=16, num_test=192, fraction_pos_train=0.5, fraction_pos_test=0.5)],
#  'CHEMBL1613898': [FSMolTaskSampleEvalResults(size=151, acc=0.5231788079470199, balanced_acc=0.5248245614035087, f1=0.6170212765957447, prec=0.5132743362831859, recall=0.7733333333333333, roc_auc=0.5583333333333333, avg_precision=0.5666508668439111, kappa=0.04948417555516693, task_name='CHEMBL1613898', seed=0, num_train=16, num_test=151, fraction_pos_train=0.5, fraction_pos_test=0.4966887417218543)],
#  'CHEMBL1737951': [FSMolTaskSampleEvalResults(size=177, acc=0.7401129943502824, balanced_acc=0.7405814905814906, f1=0.6805555555555556, prec=0.6282051282051282, recall=0.7424242424242424, roc_auc=0.7568250068250068, avg_precision=0.6429906293927513, kappa=0.4640600315955766, task_name='CHEMBL1737951', seed=0, num_train=16, num_test=177, fraction_pos_train=0.375, fraction_pos_test=0.3728813559322034)],
#  'CHEMBL1614508': [FSMolTaskSampleEvalResults(size=153, acc=0.8104575163398693, balanced_acc=0.8024691358024691, f1=0.7679999999999999, prec=0.9056603773584906, recall=0.6666666666666666, roc_auc=0.8773148148148149, avg_precision=0.8703612024837993, kappa=0.6139389193422083, task_name='CHEMBL1614508', seed=0, num_train=16, num_test=153, fraction_pos_train=0.4375, fraction_pos_test=0.47058823529411764)],
#  'CHEMBL1738362': [FSMolTaskSampleEvalResults(size=123, acc=0.7317073170731707, balanced_acc=0.5803405572755418, f1=0.2978723404255319, prec=0.7777777777777778, recall=0.18421052631578946, roc_auc=0.6777089783281733, avg_precision=0.5339600196668046, kappa=0.2036492054149499, task_name='CHEMBL1738362', seed=0, num_train=16, num_test=123, fraction_pos_train=0.3125, fraction_pos_test=0.3089430894308943)],
#  'CHEMBL1738633': [FSMolTaskSampleEvalResults(size=131, acc=0.5572519083969466, balanced_acc=0.5596736596736597, f1=0.6627906976744186, prec=0.5327102803738317, recall=0.8769230769230769, roc_auc=0.652913752913753, avg_precision=0.6351033814394452, kappa=0.11876594757596848, task_name='CHEMBL1738633', seed=0, num_train=16, num_test=131, fraction_pos_train=0.5, fraction_pos_test=0.4961832061068702)],
#  'CHEMBL1119333': [FSMolTaskSampleEvalResults(size=401, acc=0.6109725685785536, balanced_acc=0.6116169154228855, f1=0.6904761904761905, prec=0.5723684210526315, recall=0.87, roc_auc=0.7254726368159206, avg_precision=0.7170253629343233, kappa=0.22294544370466063, task_name='CHEMBL1119333', seed=0, num_train=16, num_test=401, fraction_pos_train=0.5, fraction_pos_test=0.49875311720698257)],
#  'CHEMBL1794519': [FSMolTaskSampleEvalResults(size=140, acc=0.7071428571428572, balanced_acc=0.7071428571428571, f1=0.6917293233082706, prec=0.7301587301587301, recall=0.6571428571428571, roc_auc=0.7735714285714287, avg_precision=0.8267552263892042, kappa=0.41428571428571426, task_name='CHEMBL1794519', seed=0, num_train=16, num_test=140, fraction_pos_train=0.5, fraction_pos_test=0.5)],
#  'CHEMBL1614433': [FSMolTaskSampleEvalResults(size=399, acc=0.5614035087719298, balanced_acc=0.5057885258554154, f1=0.21524663677130046, prec=0.4444444444444444, recall=0.14201183431952663, roc_auc=0.4742603550295858, avg_precision=0.4368880481439701, kappa=0.012725344644750614, task_name='CHEMBL1614433', seed=0, num_train=16, num_test=399, fraction_pos_train=0.4375, fraction_pos_test=0.42355889724310775)],
#  'CHEMBL1963721': [FSMolTaskSampleEvalResults(size=331, acc=0.6858006042296072, balanced_acc=0.5209059956817804, f1=0.08771929824561403, prec=0.8333333333333334, recall=0.046296296296296294, roc_auc=0.5205323036040524, avg_precision=0.4048964244746433, kappa=0.0552719688237554, task_name='CHEMBL1963721', seed=0, num_train=16, num_test=331, fraction_pos_train=0.3125, fraction_pos_test=0.32628398791540786)],
#  'CHEMBL1614423': [FSMolTaskSampleEvalResults(size=513, acc=0.6530214424951267, balanced_acc=0.5624334784712144, f1=0.288, prec=0.6545454545454545, recall=0.18461538461538463, roc_auc=0.6080309627479439, avg_precision=0.520458431535832, kappa=0.14500000000000002, task_name='CHEMBL1614423', seed=0, num_train=16, num_test=513, fraction_pos_train=0.375, fraction_pos_test=0.38011695906432746)],
#  'CHEMBL1614466': [FSMolTaskSampleEvalResults(size=545, acc=0.544954128440367, balanced_acc=0.47645829874370466, f1=0.09489051094890509, prec=0.2826086956521739, recall=0.05701754385964912, roc_auc=0.4858113343295146, avg_precision=0.40768885210806355, kappa=-0.0530252271062841, task_name='CHEMBL1614466', seed=0, num_train=16, num_test=545, fraction_pos_train=0.4375, fraction_pos_test=0.41834862385321103)],
#  'CHEMBL1963824': [FSMolTaskSampleEvalResults(size=407, acc=0.601965601965602, balanced_acc=0.5707207207207208, f1=0.3414634146341463, prec=0.6885245901639344, recall=0.22702702702702704, roc_auc=0.6190528366204043, avg_precision=0.581984327192101, kappa=0.14980916030534364, task_name='CHEMBL1963824', seed=0, num_train=16, num_test=407, fraction_pos_train=0.4375, fraction_pos_test=0.45454545454545453)],
#  'CHEMBL1963969': [FSMolTaskSampleEvalResults(size=224, acc=0.48214285714285715, balanced_acc=0.48214285714285715, f1=0.43689320388349523, prec=0.4787234042553192, recall=0.4017857142857143, roc_auc=0.476921237244898, avg_precision=0.4972303516547773, kappa=-0.03571428571428581, task_name='CHEMBL1963969', seed=0, num_train=16, num_test=224, fraction_pos_train=0.5, fraction_pos_test=0.5)],
#  'CHEMBL1614503': [FSMolTaskSampleEvalResults(size=118, acc=0.7033898305084746, balanced_acc=0.527027027027027, f1=0.10256410256410257, prec=1.0, recall=0.05405405405405406, roc_auc=0.6431431431431431, avg_precision=0.4961162402694678, kappa=0.07274360125729673, task_name='CHEMBL1614503', seed=0, num_train=16, num_test=118, fraction_pos_train=0.3125, fraction_pos_test=0.3135593220338983)],
#  'CHEMBL1614522': [FSMolTaskSampleEvalResults(size=742, acc=0.555256064690027, balanced_acc=0.5560229584423133, f1=0.6533613445378151, prec=0.5343642611683849, recall=0.8405405405405405, roc_auc=0.6087656204591689, avg_precision=0.5834620122341652, kappa=0.11187360357484843, task_name='CHEMBL1614522', seed=0, num_train=16, num_test=742, fraction_pos_train=0.5, fraction_pos_test=0.49865229110512127)],
#  'CHEMBL1738079': [FSMolTaskSampleEvalResults(size=216, acc=0.47685185185185186, balanced_acc=0.4796653796653797, f1=0.5191489361702128, prec=0.46923076923076923, recall=0.580952380952381, roc_auc=0.47198627198627197, avg_precision=0.47803652010175235, kappa=-0.04040920716112528, task_name='CHEMBL1738079', seed=0, num_train=16, num_test=216, fraction_pos_train=0.5, fraction_pos_test=0.4861111111111111)],
#  'CHEMBL1738502': [FSMolTaskSampleEvalResults(size=688, acc=0.6526162790697675, balanced_acc=0.506198347107438, f1=0.024489795918367346, prec=1.0, recall=0.012396694214876033, roc_auc=0.5099646073453656, avg_precision=0.3650237264882197, kappa=0.016013595997797947, task_name='CHEMBL1738502', seed=0, num_train=16, num_test=688, fraction_pos_train=0.375, fraction_pos_test=0.35174418604651164)],
#  'CHEMBL1738485': [FSMolTaskSampleEvalResults(size=286, acc=0.5314685314685315, balanced_acc=0.5314685314685315, f1=0.5179856115107913, prec=0.5333333333333333, recall=0.5034965034965035, roc_auc=0.552154139566727, avg_precision=0.5665388382847075, kappa=0.06293706293706292, task_name='CHEMBL1738485', seed=0, num_train=16, num_test=286, fraction_pos_train=0.5, fraction_pos_test=0.5)],
#  'CHEMBL1738395': [FSMolTaskSampleEvalResults(size=159, acc=0.5031446540880503, balanced_acc=0.5030063291139241, f1=0.4903225806451613, prec=0.5, recall=0.4810126582278481, roc_auc=0.47753164556962024, avg_precision=0.48552261205801944, kappa=0.0060140856215873395, task_name='CHEMBL1738395', seed=0, num_train=16, num_test=159, fraction_pos_train=0.5, fraction_pos_test=0.4968553459119497)],
#  'CHEMBL1738579': [FSMolTaskSampleEvalResults(size=198, acc=0.5404040404040404, balanced_acc=0.5494623655913979, f1=0.5882352941176471, prec=0.5078125, recall=0.6989247311827957, roc_auc=0.5426011264720942, avg_precision=0.49452755956342925, kappa=0.09684210526315784, task_name='CHEMBL1738579', seed=0, num_train=16, num_test=198, fraction_pos_train=0.5, fraction_pos_test=0.4696969696969697)],
#  'CHEMBL1963705': [FSMolTaskSampleEvalResults(size=675, acc=0.6533333333333333, balanced_acc=0.6103510885001888, f1=0.4454976303317536, prec=0.6911764705882353, recall=0.32867132867132864, roc_auc=0.7074487209448649, avg_precision=0.6501082784895061, kappa=0.23717026147263087, task_name='CHEMBL1963705', seed=0, num_train=16, num_test=675, fraction_pos_train=0.4375, fraction_pos_test=0.4237037037037037)],
#  'CHEMBL1963827': [FSMolTaskSampleEvalResults(size=597, acc=0.5946398659966499, balanced_acc=0.5936293436293436, f1=0.5363984674329502, prec=0.6194690265486725, recall=0.47297297297297297, roc_auc=0.6307297746251233, avg_precision=0.6241731661018398, kappa=0.18762721966689533, task_name='CHEMBL1963827', seed=0, num_train=16, num_test=597, fraction_pos_train=0.5, fraction_pos_test=0.49581239530988275)],
#  'CHEMBL1963799': [FSMolTaskSampleEvalResults(size=345, acc=0.6289855072463768, balanced_acc=0.5319197849614486, f1=0.1688311688311688, prec=0.65, recall=0.09701492537313433, roc_auc=0.6220909669661172, avg_precision=0.4982362051693447, kappa=0.07557044169981164, task_name='CHEMBL1963799', seed=0, num_train=16, num_test=345, fraction_pos_train=0.375, fraction_pos_test=0.3884057971014493)],
#  'CHEMBL1963818': [FSMolTaskSampleEvalResults(size=594, acc=0.6582491582491582, balanced_acc=0.6291275813490018, f1=0.4727272727272727, prec=0.7711864406779662, recall=0.3408239700374532, roc_auc=0.6700569242575222, avg_precision=0.6742412046573361, kappa=0.2721906348459059, task_name='CHEMBL1963818', seed=0, num_train=16, num_test=594, fraction_pos_train=0.4375, fraction_pos_test=0.4494949494949495)],
#  'CHEMBL1794557': [FSMolTaskSampleEvalResults(size=836, acc=0.5107655502392344, balanced_acc=0.5107655502392344, f1=0.5559174809989141, prec=0.5089463220675944, recall=0.6124401913875598, roc_auc=0.5233682836931389, avg_precision=0.5225935831238978, kappa=0.021531100478468845, task_name='CHEMBL1794557', seed=0, num_train=16, num_test=836, fraction_pos_train=0.5, fraction_pos_test=0.5)],
#  'CHEMBL1963838': [FSMolTaskSampleEvalResults(size=224, acc=0.5178571428571429, balanced_acc=0.5178571428571428, f1=0.5221238938053097, prec=0.5175438596491229, recall=0.5267857142857143, roc_auc=0.5128348214285714, avg_precision=0.5179413673087903, kappa=0.0357142857142857, task_name='CHEMBL1963838', seed=0, num_train=16, num_test=224, fraction_pos_train=0.5, fraction_pos_test=0.5)],
#  'CHEMBL1963831': [FSMolTaskSampleEvalResults(size=374, acc=0.660427807486631, balanced_acc=0.5633338352657732, f1=0.23030303030303031, prec=0.95, recall=0.1310344827586207, roc_auc=0.6888872157807558, avg_precision=0.6242969963482392, kappa=0.1504560901448757, task_name='CHEMBL1963831', seed=0, num_train=16, num_test=374, fraction_pos_train=0.375, fraction_pos_test=0.3877005347593583)],
#  'CHEMBL1964005': [FSMolTaskSampleEvalResults(size=149, acc=0.5906040268456376, balanced_acc=0.5883783783783784, f1=0.3838383838383838, prec=0.76, recall=0.25675675675675674, roc_auc=0.6100900900900902, avg_precision=0.6571368672687551, kappa=0.1775404940729346, task_name='CHEMBL1964005', seed=0, num_train=16, num_test=149, fraction_pos_train=0.5, fraction_pos_test=0.4966442953020134)],
#  'CHEMBL1963731': [FSMolTaskSampleEvalResults(size=624, acc=0.6185897435897436, balanced_acc=0.5097788931677556, f1=0.048, prec=0.75, recall=0.024793388429752067, roc_auc=0.6960592358617108, avg_precision=0.5941213444468312, kappa=0.023769457299116392, task_name='CHEMBL1963731', seed=0, num_train=16, num_test=624, fraction_pos_train=0.375, fraction_pos_test=0.38782051282051283)],
#  'CHEMBL1964106': [FSMolTaskSampleEvalResults(size=300, acc=0.66, balanced_acc=0.5, f1=0.0, prec=1.0, recall=0.0, roc_auc=0.47794117647058826, avg_precision=0.33774422296095097, kappa=0.0, task_name='CHEMBL1964106', seed=0, num_train=16, num_test=300, fraction_pos_train=0.3125, fraction_pos_test=0.34)],
#  'CHEMBL2219020': [FSMolTaskSampleEvalResults(size=141, acc=0.49645390070921985, balanced_acc=0.49688128772635815, f1=0.5234899328859061, prec=0.4936708860759494, recall=0.5571428571428572, roc_auc=0.4989939637826962, avg_precision=0.509648991388555, kappa=-0.006231782088651938, task_name='CHEMBL2219020', seed=0, num_train=16, num_test=141, fraction_pos_train=0.5, fraction_pos_test=0.49645390070921985)],
#  'CHEMBL2219026': [FSMolTaskSampleEvalResults(size=141, acc=0.524822695035461, balanced_acc=0.5087878787878788, f1=0.3366336633663366, prec=0.4857142857142857, recall=0.25757575757575757, roc_auc=0.5101010101010102, avg_precision=0.5170685235984563, kappa=0.01808543810414709, task_name='CHEMBL2219026', seed=0, num_train=16, num_test=141, fraction_pos_train=0.5, fraction_pos_test=0.46808510638297873)],
#  'CHEMBL1963819': [FSMolTaskSampleEvalResults(size=715, acc=0.6559440559440559, balanced_acc=0.5135483870967742, f1=0.07518796992481203, prec=0.625, recall=0.04, roc_auc=0.5841118279569892, avg_precision=0.4236227290054768, kappa=0.03457928536143584, task_name='CHEMBL1963819', seed=0, num_train=16, num_test=715, fraction_pos_train=0.375, fraction_pos_test=0.34965034965034963)],
#  'CHEMBL1794504': [FSMolTaskSampleEvalResults(size=114, acc=0.6578947368421053, balanced_acc=0.6570197044334976, f1=0.6776859504132232, prec=0.6507936507936508, recall=0.7068965517241379, roc_auc=0.6839593596059113, avg_precision=0.702259131834888, kappa=0.3145235892691951, task_name='CHEMBL1794504', seed=0, num_train=16, num_test=114, fraction_pos_train=0.5, fraction_pos_test=0.5087719298245614)],
#  'CHEMBL1963810': [FSMolTaskSampleEvalResults(size=654, acc=0.6039755351681957, balanced_acc=0.5978789155780306, f1=0.512241054613936, prec=0.6296296296296297, recall=0.43174603174603177, roc_auc=0.5988060120803484, avg_precision=0.6186171128141968, kappa=0.1979601693229921, task_name='CHEMBL1963810', seed=0, num_train=16, num_test=654, fraction_pos_train=0.5, fraction_pos_test=0.481651376146789)],
#  'CHEMBL2218994': [FSMolTaskSampleEvalResults(size=141, acc=0.524822695035461, balanced_acc=0.5162363856393707, f1=0.4070796460176991, prec=0.5, recall=0.34328358208955223, roc_auc=0.5684751916095201, avg_precision=0.5361460246863327, kappa=0.032961408537209524, task_name='CHEMBL2218994', seed=0, num_train=16, num_test=141, fraction_pos_train=0.5, fraction_pos_test=0.475177304964539)],
#  'CHEMBL1963715': [FSMolTaskSampleEvalResults(size=875, acc=0.6171428571428571, balanced_acc=0.5097581317764804, f1=0.12532637075718014, prec=0.4528301886792453, recall=0.07272727272727272, roc_auc=0.617022518765638, avg_precision=0.46554458463453097, kappa=0.02338869546385902, task_name='CHEMBL1963715', seed=0, num_train=16, num_test=875, fraction_pos_train=0.375, fraction_pos_test=0.37714285714285717)],
#  'CHEMBL1963701': [FSMolTaskSampleEvalResults(size=904, acc=0.5298672566371682, balanced_acc=0.5298672566371682, f1=0.6382978723404256, prec=0.5186721991701245, recall=0.8296460176991151, roc_auc=0.5609018912992404, avg_precision=0.548122656109744, kappa=0.05973451327433632, task_name='CHEMBL1963701', seed=0, num_train=16, num_test=904, fraction_pos_train=0.5, fraction_pos_test=0.5)],
#  'CHEMBL1963910': [FSMolTaskSampleEvalResults(size=184, acc=0.5597826086956522, balanced_acc=0.5597826086956521, f1=0.4635761589403974, prec=0.5932203389830508, recall=0.3804347826086957, roc_auc=0.5334357277882797, avg_precision=0.5803154659502902, kappa=0.11956521739130432, task_name='CHEMBL1963910', seed=0, num_train=16, num_test=184, fraction_pos_train=0.5, fraction_pos_test=0.5)],
#  'CHEMBL1963741': [FSMolTaskSampleEvalResults(size=911, acc=0.570801317233809, balanced_acc=0.546418491484185, f1=0.38425196850393706, prec=0.5446428571428571, recall=0.29683698296836986, roc_auc=0.5477226277372262, avg_precision=0.5365887915160812, kappa=0.09675497074985362, task_name='CHEMBL1963741', seed=0, num_train=16, num_test=911, fraction_pos_train=0.4375, fraction_pos_test=0.45115257958287597)],
#  'CHEMBL1963773': [FSMolTaskSampleEvalResults(size=507, acc=0.5877712031558185, balanced_acc=0.5754237288135593, f1=0.503562945368171, prec=0.507177033492823, recall=0.5, roc_auc=0.5586664534697793, avg_precision=0.5169649766231204, kappa=0.15114835257267822, task_name='CHEMBL1963773', seed=0, num_train=16, num_test=507, fraction_pos_train=0.4375, fraction_pos_test=0.4181459566074951)],
#  'CHEMBL1963723': [FSMolTaskSampleEvalResults(size=840, acc=0.49404761904761907, balanced_acc=0.4650404785438008, f1=0.19659735349716448, prec=0.3561643835616438, recall=0.13577023498694518, roc_auc=0.4649833458073141, avg_precision=0.43685776629249806, kappa=-0.07360671710914102, task_name='CHEMBL1963723', seed=0, num_train=16, num_test=840, fraction_pos_train=0.4375, fraction_pos_test=0.45595238095238094)],
#  'CHEMBL1963825': [FSMolTaskSampleEvalResults(size=390, acc=0.6230769230769231, balanced_acc=0.5957269037956553, f1=0.4189723320158103, prec=0.6973684210526315, recall=0.2994350282485876, roc_auc=0.661693323784515, avg_precision=0.6009909720866385, kappa=0.20115374968648103, task_name='CHEMBL1963825', seed=0, num_train=16, num_test=390, fraction_pos_train=0.4375, fraction_pos_test=0.45384615384615384)],
#  'CHEMBL2219028': [FSMolTaskSampleEvalResults(size=141, acc=0.5390070921985816, balanced_acc=0.540241448692153, f1=0.6060606060606061, prec=0.5263157894736842, recall=0.7142857142857143, roc_auc=0.5079476861167002, avg_precision=0.4904289766961357, kappa=0.08028098344204726, task_name='CHEMBL2219028', seed=0, num_train=16, num_test=141, fraction_pos_train=0.5, fraction_pos_test=0.49645390070921985)],
#  'CHEMBL1964101': [FSMolTaskSampleEvalResults(size=978, acc=0.5408997955010225, balanced_acc=0.5401890264302442, f1=0.2951334379905808, prec=0.6308724832214765, recall=0.19262295081967212, roc_auc=0.5735823017731683, avg_precision=0.568282773805741, kappa=0.08049216646215562, task_name='CHEMBL1964101', seed=0, num_train=16, num_test=978, fraction_pos_train=0.5, fraction_pos_test=0.49897750511247446)],
#  'CHEMBL1738573': [FSMolTaskSampleEvalResults(size=1450, acc=0.5344827586206896, balanced_acc=0.5344827586206897, f1=0.534803583735355, prec=0.5344352617079889, recall=0.5351724137931034, roc_auc=0.5350887039239002, avg_precision=0.5374455378559453, kappa=0.06896551724137934, task_name='CHEMBL1738573', seed=0, num_train=16, num_test=1450, fraction_pos_train=0.5, fraction_pos_test=0.5)],
#  'CHEMBL2218946': [FSMolTaskSampleEvalResults(size=141, acc=0.624113475177305, balanced_acc=0.6271135265700483, f1=0.6666666666666666, prec=0.5888888888888889, recall=0.7681159420289855, roc_auc=0.6507648953301127, avg_precision=0.6294504442789628, kappa=0.2526252625262526, task_name='CHEMBL2218946', seed=0, num_train=16, num_test=141, fraction_pos_train=0.5, fraction_pos_test=0.48936170212765956)],
#  'CHEMBL1614292': [FSMolTaskSampleEvalResults(size=1564, acc=0.6464194373401535, balanced_acc=0.503809102658822, f1=0.0547008547008547, prec=0.42105263157894735, recall=0.029250457038391225, roc_auc=0.5457164222837, avg_precision=0.38850707241680893, kappa=0.009704958276465558, task_name='CHEMBL1614292', seed=0, num_train=16, num_test=1564, fraction_pos_train=0.375, fraction_pos_test=0.34974424552429667)],
#  'CHEMBL2219040': [FSMolTaskSampleEvalResults(size=141, acc=0.49645390070921985, balanced_acc=0.498692152917505, f1=0.6162162162162163, prec=0.4956521739130435, recall=0.8142857142857143, roc_auc=0.5296780684104628, avg_precision=0.5416609990385807, kappa=-0.0026039058587881136, task_name='CHEMBL2219040', seed=0, num_train=16, num_test=141, fraction_pos_train=0.5, fraction_pos_test=0.49645390070921985)],
#  'CHEMBL2218959': [FSMolTaskSampleEvalResults(size=141, acc=0.5531914893617021, balanced_acc=0.5539235412474849, f1=0.5935483870967742, prec=0.5411764705882353, recall=0.6571428571428571, roc_auc=0.6190140845070422, avg_precision=0.6549020380756931, kappa=0.10768458061275743, task_name='CHEMBL2218959', seed=0, num_train=16, num_test=141, fraction_pos_train=0.5, fraction_pos_test=0.49645390070921985)],
#  'CHEMBL1613800': [FSMolTaskSampleEvalResults(size=1866, acc=0.5986066452304395, balanced_acc=0.5005901934322987, f1=0.045859872611464965, prec=0.4090909090909091, recall=0.024291497975708502, roc_auc=0.5135066726645674, avg_precision=0.40984603569096145, kappa=0.0014061140238438297, task_name='CHEMBL1613800', seed=0, num_train=16, num_test=1866, fraction_pos_train=0.375, fraction_pos_test=0.3971061093247588)],
#  'CHEMBL2218957': [FSMolTaskSampleEvalResults(size=141, acc=0.6170212765957447, balanced_acc=0.6185110663983904, f1=0.6823529411764706, prec=0.58, recall=0.8285714285714286, roc_auc=0.6648893360160966, avg_precision=0.618210157105001, kappa=0.2363089267803411, task_name='CHEMBL2218957', seed=0, num_train=16, num_test=141, fraction_pos_train=0.5, fraction_pos_test=0.49645390070921985)],
#  'CHEMBL1794324': [FSMolTaskSampleEvalResults(size=2053, acc=0.49001461276181196, balanced_acc=0.48589913105591714, f1=0.39792984473835535, prec=0.46567967698519513, recall=0.3473895582329317, roc_auc=0.49112770856367766, avg_precision=0.48999068996557454, kappa=-0.028409974398488913, task_name='CHEMBL1794324', seed=0, num_train=16, num_test=2053, fraction_pos_train=0.5, fraction_pos_test=0.48514369215781783)],
#  'CHEMBL1614027': [FSMolTaskSampleEvalResults(size=2977, acc=0.5606315082297615, balanced_acc=0.5607284352142464, f1=0.5842339478703116, prec=0.5536144578313253, recall=0.6184387617765814, roc_auc=0.5640087722386359, avg_precision=0.5336204355998514, kappa=0.1214330291449558, task_name='CHEMBL1614027', seed=0, num_train=16, num_test=2977, fraction_pos_train=0.5, fraction_pos_test=0.49916022841787033)],
#  'CHEMBL1963756': [FSMolTaskSampleEvalResults(size=746, acc=0.5924932975871313, balanced_acc=0.5344440505730829, f1=0.2692307692307692, prec=0.5384615384615384, recall=0.1794871794871795, roc_auc=0.5747001654259718, avg_precision=0.4956682751180288, kappa=0.07601043024771847, task_name='CHEMBL1963756', seed=0, num_train=16, num_test=746, fraction_pos_train=0.4375, fraction_pos_test=0.41823056300268097)],
#  'CHEMBL1614153': [FSMolTaskSampleEvalResults(size=3072, acc=0.6650390625, balanced_acc=0.5002411705189732, f1=0.0019398642095053344, prec=0.5, recall=0.0009718172983479105, roc_auc=0.5335020099921656, avg_precision=0.3551946843315744, kappa=0.0006411399392244332, task_name='CHEMBL1614153', seed=0, num_train=16, num_test=3072, fraction_pos_train=0.3125, fraction_pos_test=0.3349609375)],
#  'CHEMBL2219059': [FSMolTaskSampleEvalResults(size=141, acc=0.5460992907801419, balanced_acc=0.5469818913480885, f1=0.5949367088607594, prec=0.5340909090909091, recall=0.6714285714285714, roc_auc=0.5748490945674045, avg_precision=0.5708243103634749, kappa=0.09379393452500506, task_name='CHEMBL2219059', seed=0, num_train=16, num_test=141, fraction_pos_train=0.5, fraction_pos_test=0.49645390070921985)],
#  'CHEMBL2219070': [FSMolTaskSampleEvalResults(size=141, acc=0.5957446808510638, balanced_acc=0.5908632513110125, f1=0.5365853658536586, prec=0.5892857142857143, recall=0.4925373134328358, roc_auc=0.6131504638967327, avg_precision=0.6384773089642781, kappa=0.18314869397296474, task_name='CHEMBL2219070', seed=0, num_train=16, num_test=141, fraction_pos_train=0.5, fraction_pos_test=0.475177304964539)],
#  'CHEMBL1613777': [FSMolTaskSampleEvalResults(size=3578, acc=0.5740637227501397, balanced_acc=0.5773165880782252, f1=0.6470588235294117, prec=0.5465571205007824, recall=0.7928490351872872, roc_auc=0.5847292574017311, avg_precision=0.5406975800758488, kappa=0.15360405807719424, task_name='CHEMBL1613777', seed=0, num_train=16, num_test=3578, fraction_pos_train=0.5, fraction_pos_test=0.4924538848518726)],
#  'CHEMBL2219076': [FSMolTaskSampleEvalResults(size=141, acc=0.5460992907801419, balanced_acc=0.5495169082125604, f1=0.6049382716049383, prec=0.5268817204301075, recall=0.7101449275362319, roc_auc=0.5770933977455718, avg_precision=0.588566653232435, kappa=0.09832134292565953, task_name='CHEMBL2219076', seed=0, num_train=16, num_test=141, fraction_pos_train=0.5, fraction_pos_test=0.48936170212765956)],
#  'CHEMBL2219088': [FSMolTaskSampleEvalResults(size=141, acc=0.48936170212765956, balanced_acc=0.4896378269617706, f1=0.5068493150684932, prec=0.4868421052631579, recall=0.5285714285714286, roc_auc=0.4789738430583501, avg_precision=0.4984534639071495, kappa=-0.02071184395736969, task_name='CHEMBL2219088', seed=0, num_train=16, num_test=141, fraction_pos_train=0.5, fraction_pos_test=0.49645390070921985)],
#  'CHEMBL1964115': [FSMolTaskSampleEvalResults(size=324, acc=0.6080246913580247, balanced_acc=0.5435951379149135, f1=0.19108280254777069, prec=0.7894736842105263, recall=0.10869565217391304, roc_auc=0.5599384447561166, avg_precision=0.5188126552173538, kappa=0.09810625986323007, task_name='CHEMBL1964115', seed=0, num_train=16, num_test=324, fraction_pos_train=0.4375, fraction_pos_test=0.42592592592592593)],
#  'CHEMBL2219093': [FSMolTaskSampleEvalResults(size=141, acc=0.5390070921985816, balanced_acc=0.5427074939564867, f1=0.5751633986928104, prec=0.5176470588235295, recall=0.6470588235294118, roc_auc=0.5793714746172441, avg_precision=0.6042208118729525, kappa=0.08468990312593627, task_name='CHEMBL2219093', seed=0, num_train=16, num_test=141, fraction_pos_train=0.5, fraction_pos_test=0.48226950354609927)],
#  'CHEMBL2219050': [FSMolTaskSampleEvalResults(size=141, acc=0.5815602836879432, balanced_acc=0.5809859154929577, f1=0.5426356589147286, prec=0.5932203389830508, recall=0.5, roc_auc=0.5669014084507042, avg_precision=0.5398931906626594, kappa=0.1621512740457246, task_name='CHEMBL2219050', seed=0, num_train=16, num_test=141, fraction_pos_train=0.5, fraction_pos_test=0.49645390070921985)],
#  'CHEMBL2219098': [FSMolTaskSampleEvalResults(size=141, acc=0.5460992907801419, balanced_acc=0.5421540943929004, f1=0.4920634920634921, prec=0.5254237288135594, recall=0.4626865671641791, roc_auc=0.5267244856797095, avg_precision=0.5206897904466585, kappa=0.0847870182555781, task_name='CHEMBL2219098', seed=0, num_train=16, num_test=141, fraction_pos_train=0.5, fraction_pos_test=0.475177304964539)],
#  'CHEMBL2219102': [FSMolTaskSampleEvalResults(size=141, acc=0.5602836879432624, balanced_acc=0.5216727716727716, f1=0.24390243902439024, prec=0.5263157894736842, recall=0.15873015873015872, roc_auc=0.5810948310948311, avg_precision=0.5113579096818126, kappa=0.04646596858638741, task_name='CHEMBL2219102', seed=0, num_train=16, num_test=141, fraction_pos_train=0.4375, fraction_pos_test=0.44680851063829785)],
#  'CHEMBL2219104': [FSMolTaskSampleEvalResults(size=141, acc=0.4326241134751773, balanced_acc=0.4399677679290894, f1=0.5238095238095238, prec=0.44, recall=0.6470588235294118, roc_auc=0.4830781627719581, avg_precision=0.48577132188640076, kappa=-0.11816019032513858, task_name='CHEMBL2219104', seed=0, num_train=16, num_test=141, fraction_pos_train=0.5, fraction_pos_test=0.48226950354609927)],
#  'CHEMBL2218989': [FSMolTaskSampleEvalResults(size=141, acc=0.75177304964539, balanced_acc=0.7528169014084507, f1=0.7826086956521738, prec=0.6923076923076923, recall=0.9, roc_auc=0.760764587525151, avg_precision=0.6910756501174469, kappa=0.5045678144764583, task_name='CHEMBL2218989', seed=0, num_train=16, num_test=141, fraction_pos_train=0.5, fraction_pos_test=0.49645390070921985)],
#  'CHEMBL2219113': [FSMolTaskSampleEvalResults(size=141, acc=0.5319148936170213, balanced_acc=0.53420523138833, f1=0.6451612903225806, prec=0.5172413793103449, recall=0.8571428571428571, roc_auc=0.5787726358148894, avg_precision=0.6205659394615911, kappa=0.06809533346685359, task_name='CHEMBL2219113', seed=0, num_train=16, num_test=141, fraction_pos_train=0.5, fraction_pos_test=0.49645390070921985)],
#  'CHEMBL2219115': [FSMolTaskSampleEvalResults(size=141, acc=0.48936170212765956, balanced_acc=0.4932514101531023, f1=0.5324675324675324, prec=0.47674418604651164, recall=0.6029411764705882, roc_auc=0.4980862207896858, avg_precision=0.49599911097875954, kappa=-0.013375923337991535, task_name='CHEMBL2219115', seed=0, num_train=16, num_test=141, fraction_pos_train=0.5, fraction_pos_test=0.48226950354609927)],
#  'CHEMBL2219120': [FSMolTaskSampleEvalResults(size=141, acc=0.46099290780141844, balanced_acc=0.46648550724637683, f1=0.5681818181818182, prec=0.4672897196261682, recall=0.7246376811594203, roc_auc=0.5070450885668277, avg_precision=0.5098827079036422, kappa=-0.0662686567164179, task_name='CHEMBL2219120', seed=0, num_train=16, num_test=141, fraction_pos_train=0.5, fraction_pos_test=0.48936170212765956)],
#  'CHEMBL2219043': [FSMolTaskSampleEvalResults(size=141, acc=0.5815602836879432, balanced_acc=0.5830985915492958, f1=0.6549707602339182, prec=0.5544554455445545, recall=0.8, roc_auc=0.5301810865191146, avg_precision=0.4895588146012076, kappa=0.16568047337278113, task_name='CHEMBL2219043', seed=0, num_train=16, num_test=141, fraction_pos_train=0.5, fraction_pos_test=0.49645390070921985)],
#  'CHEMBL2219150': [FSMolTaskSampleEvalResults(size=141, acc=0.6382978723404256, balanced_acc=0.6398390342052314, f1=0.7017543859649122, prec=0.594059405940594, recall=0.8571428571428571, roc_auc=0.6836016096579477, avg_precision=0.6268186614004014, kappa=0.2788085447798616, task_name='CHEMBL2219150', seed=0, num_train=16, num_test=141, fraction_pos_train=0.5, fraction_pos_test=0.49645390070921985)],
#  'CHEMBL2219159': [FSMolTaskSampleEvalResults(size=141, acc=0.5106382978723404, balanced_acc=0.5248791297340855, f1=0.6461538461538462, prec=0.49606299212598426, recall=0.9264705882352942, roc_auc=0.5227639000805802, avg_precision=0.5486319488962299, kappa=0.048322410251394055, task_name='CHEMBL2219159', seed=0, num_train=16, num_test=141, fraction_pos_train=0.5, fraction_pos_test=0.48226950354609927)],
#  'CHEMBL2219047': [FSMolTaskSampleEvalResults(size=141, acc=0.5460992907801419, balanced_acc=0.5562726906010488, f1=0.6144578313253012, prec=0.5151515151515151, recall=0.7611940298507462, roc_auc=0.6022589753933038, avg_precision=0.5416034111195605, kappa=0.11005917159763312, task_name='CHEMBL2219047', seed=0, num_train=16, num_test=141, fraction_pos_train=0.5, fraction_pos_test=0.475177304964539)],
#  'CHEMBL2219161': [FSMolTaskSampleEvalResults(size=141, acc=0.5106382978723404, balanced_acc=0.510764587525151, f1=0.5174825174825174, prec=0.5068493150684932, recall=0.5285714285714286, roc_auc=0.5715291750503019, avg_precision=0.5495117286007116, kappa=0.021522679271849587, task_name='CHEMBL2219161', seed=0, num_train=16, num_test=141, fraction_pos_train=0.5, fraction_pos_test=0.49645390070921985)],
#  'CHEMBL2219164': [FSMolTaskSampleEvalResults(size=141, acc=0.5177304964539007, balanced_acc=0.5187122736418511, f1=0.575, prec=0.5111111111111111, recall=0.6571428571428571, roc_auc=0.5463782696177063, avg_precision=0.5402229046279265, kappa=0.03734939759036149, task_name='CHEMBL2219164', seed=0, num_train=16, num_test=141, fraction_pos_train=0.5, fraction_pos_test=0.49645390070921985)],
#  'CHEMBL2219045': [FSMolTaskSampleEvalResults(size=141, acc=0.5815602836879432, balanced_acc=0.5803140096618358, f1=0.549618320610687, prec=0.5806451612903226, recall=0.5217391304347826, roc_auc=0.5973228663446055, avg_precision=0.5505687784712959, kappa=0.16096822995461413, task_name='CHEMBL2219045', seed=0, num_train=16, num_test=141, fraction_pos_train=0.5, fraction_pos_test=0.48936170212765956)],
#  'CHEMBL2219174': [FSMolTaskSampleEvalResults(size=141, acc=0.5531914893617021, balanced_acc=0.5548289738430583, f1=0.6358381502890172, prec=0.5339805825242718, recall=0.7857142857142857, roc_auc=0.5835010060362172, avg_precision=0.5898863222212556, kappa=0.10929509676125548, task_name='CHEMBL2219174', seed=0, num_train=16, num_test=141, fraction_pos_train=0.5, fraction_pos_test=0.49645390070921985)],
#  'CHEMBL2219175': [FSMolTaskSampleEvalResults(size=141, acc=0.5319148936170213, balanced_acc=0.5054545454545455, f1=0.15384615384615385, prec=0.5, recall=0.09090909090909091, roc_auc=0.5065656565656566, avg_precision=0.491226103364795, kappa=0.01147227533460804, task_name='CHEMBL2219175', seed=0, num_train=16, num_test=141, fraction_pos_train=0.5, fraction_pos_test=0.46808510638297873)],
#  'CHEMBL2219180': [FSMolTaskSampleEvalResults(size=141, acc=0.5815602836879432, balanced_acc=0.5866545893719807, f1=0.6589595375722545, prec=0.5480769230769231, recall=0.8260869565217391, roc_auc=0.6042673107890499, avg_precision=0.5448311507322297, kappa=0.17149686286226473, task_name='CHEMBL2219180', seed=0, num_train=16, num_test=141, fraction_pos_train=0.5, fraction_pos_test=0.48936170212765956)],
#  'CHEMBL2219146': [FSMolTaskSampleEvalResults(size=141, acc=0.5531914893617021, balanced_acc=0.5563380281690141, f1=0.6896551724137931, prec=0.5263157894736842, recall=1.0, roc_auc=0.6028169014084507, avg_precision=0.5727128015592796, kappa=0.11196641007697694, task_name='CHEMBL2219146', seed=0, num_train=16, num_test=141, fraction_pos_train=0.5, fraction_pos_test=0.49645390070921985)],
#  'CHEMBL2219189': [FSMolTaskSampleEvalResults(size=141, acc=0.5106382978723404, balanced_acc=0.5122736418511067, f1=0.6011560693641619, prec=0.5048543689320388, recall=0.7428571428571429, roc_auc=0.48370221327967805, avg_precision=0.4830843145810573, kappa=0.024466058357565434, task_name='CHEMBL2219189', seed=0, num_train=16, num_test=141, fraction_pos_train=0.5, fraction_pos_test=0.49645390070921985)],
#  'CHEMBL2219191': [FSMolTaskSampleEvalResults(size=141, acc=0.5815602836879432, balanced_acc=0.5703030303030303, f1=0.4684684684684684, prec=0.5777777777777777, recall=0.3939393939393939, roc_auc=0.6518181818181819, avg_precision=0.6197626024593405, kappa=0.1433426011739265, task_name='CHEMBL2219191', seed=0, num_train=16, num_test=141, fraction_pos_train=0.5, fraction_pos_test=0.46808510638297873)],
#  'CHEMBL2219198': [FSMolTaskSampleEvalResults(size=141, acc=0.6170212765957447, balanced_acc=0.6175050301810865, f1=0.64, prec=0.6, recall=0.6857142857142857, roc_auc=0.6536217303822938, avg_precision=0.6758422314396836, kappa=0.23477386934673372, task_name='CHEMBL2219198', seed=0, num_train=16, num_test=141, fraction_pos_train=0.5, fraction_pos_test=0.49645390070921985)],
#  'CHEMBL2219203': [FSMolTaskSampleEvalResults(size=141, acc=0.574468085106383, balanced_acc=0.5861234368697056, f1=0.6470588235294117, prec=0.5339805825242718, recall=0.8208955223880597, roc_auc=0.6019564340459863, avg_precision=0.5994030329254647, kappa=0.16797797010228166, task_name='CHEMBL2219203', seed=0, num_train=16, num_test=141, fraction_pos_train=0.5, fraction_pos_test=0.475177304964539)],
#  'CHEMBL2219075': [FSMolTaskSampleEvalResults(size=141, acc=0.6312056737588653, balanced_acc=0.6308853118712274, f1=0.6119402985074627, prec=0.640625, recall=0.5857142857142857, roc_auc=0.6892354124748491, avg_precision=0.6274061628100126, kappa=0.261928729615462, task_name='CHEMBL2219075', seed=0, num_train=16, num_test=141, fraction_pos_train=0.5, fraction_pos_test=0.49645390070921985)],
#  'CHEMBL2219223': [FSMolTaskSampleEvalResults(size=141, acc=0.5319148936170213, balanced_acc=0.5338436744560838, f1=0.547945205479452, prec=0.5128205128205128, recall=0.5882352941176471, roc_auc=0.5692989524576955, avg_precision=0.5765287483190449, kappa=0.06734816596512327, task_name='CHEMBL2219223', seed=0, num_train=16, num_test=141, fraction_pos_train=0.5, fraction_pos_test=0.48226950354609927)],
#  'CHEMBL2219225': [FSMolTaskSampleEvalResults(size=141, acc=0.49645390070921985, balanced_acc=0.4980885311871227, f1=0.5895953757225434, prec=0.49514563106796117, recall=0.7285714285714285, roc_auc=0.5170020120724346, avg_precision=0.5414714707017324, kappa=-0.0038102877769978782, task_name='CHEMBL2219225', seed=0, num_train=16, num_test=141, fraction_pos_train=0.5, fraction_pos_test=0.49645390070921985)],
#  'CHEMBL2219232': [FSMolTaskSampleEvalResults(size=141, acc=0.5035460992907801, balanced_acc=0.5038229376257545, f1=0.5205479452054795, prec=0.5, recall=0.5428571428571428, roc_auc=0.5193158953722334, avg_precision=0.5014884340020767, kappa=0.0076412628192239485, task_name='CHEMBL2219232', seed=0, num_train=16, num_test=141, fraction_pos_train=0.5, fraction_pos_test=0.49645390070921985)],
#  'CHEMBL2219236': [FSMolTaskSampleEvalResults(size=141, acc=0.5957446808510638, balanced_acc=0.5968812877263581, f1=0.6503067484662578, prec=0.5698924731182796, recall=0.7571428571428571, roc_auc=0.6382293762575453, avg_precision=0.6243739609960706, kappa=0.19331526648599828, task_name='CHEMBL2219236', seed=0, num_train=16, num_test=141, fraction_pos_train=0.5, fraction_pos_test=0.49645390070921985)],
#  'CHEMBL2219244': [FSMolTaskSampleEvalResults(size=141, acc=0.5390070921985816, balanced_acc=0.5422705314009661, f1=0.5962732919254657, prec=0.5217391304347826, recall=0.6956521739130435, roc_auc=0.6060789049919485, avg_precision=0.6000626405183592, kappa=0.08395802098950522, task_name='CHEMBL2219244', seed=0, num_train=16, num_test=141, fraction_pos_train=0.5, fraction_pos_test=0.48936170212765956)],
#  'CHEMBL2219049': [FSMolTaskSampleEvalResults(size=141, acc=0.5886524822695035, balanced_acc=0.5896378269617706, f1=0.6375, prec=0.5666666666666667, recall=0.7285714285714285, roc_auc=0.5987927565392355, avg_precision=0.5471302592341833, kappa=0.17891566265060244, task_name='CHEMBL2219049', seed=0, num_train=16, num_test=141, fraction_pos_train=0.5, fraction_pos_test=0.49645390070921985)],
#  'CHEMBL2219242': [FSMolTaskSampleEvalResults(size=141, acc=0.5957446808510638, balanced_acc=0.5628828093099224, f1=0.3870967741935484, prec=0.5806451612903226, recall=0.2903225806451613, roc_auc=0.5772764393630052, avg_precision=0.5336500250009991, kappa=0.13291617218685947, task_name='CHEMBL2219242', seed=0, num_train=16, num_test=141, fraction_pos_train=0.4375, fraction_pos_test=0.4397163120567376)],
#  'CHEMBL2219267': [FSMolTaskSampleEvalResults(size=141, acc=0.5460992907801419, balanced_acc=0.5472837022132797, f1=0.6097560975609756, prec=0.5319148936170213, recall=0.7142857142857143, roc_auc=0.5238430583501006, avg_precision=0.487786654025595, kappa=0.09433962264150952, task_name='CHEMBL2219267', seed=0, num_train=16, num_test=141, fraction_pos_train=0.5, fraction_pos_test=0.49645390070921985)],
#  'CHEMBL2219270': [FSMolTaskSampleEvalResults(size=141, acc=0.5035460992907801, balanced_acc=0.5054391619661563, f1=0.5205479452054794, prec=0.48717948717948717, recall=0.5588235294117647, roc_auc=0.48438759065269943, avg_precision=0.4852863105223846, kappa=0.010823812387252052, task_name='CHEMBL2219270', seed=0, num_train=16, num_test=141, fraction_pos_train=0.5, fraction_pos_test=0.48226950354609927)],
#  'CHEMBL2219194': [FSMolTaskSampleEvalResults(size=141, acc=0.5531914893617021, balanced_acc=0.5715006050826946, f1=0.6666666666666667, prec=0.5163934426229508, recall=0.9402985074626866, roc_auc=0.6226300927793464, avg_precision=0.6204428023575554, kappa=0.13765653820017476, task_name='CHEMBL2219194', seed=0, num_train=16, num_test=141, fraction_pos_train=0.5, fraction_pos_test=0.475177304964539)],
#  'CHEMBL2219272': [FSMolTaskSampleEvalResults(size=141, acc=0.5602836879432624, balanced_acc=0.5591549295774648, f1=0.4745762711864407, prec=0.5833333333333334, recall=0.4, roc_auc=0.657645875251509, avg_precision=0.6302304132228209, kappa=0.11857229280096793, task_name='CHEMBL2219272', seed=0, num_train=16, num_test=141, fraction_pos_train=0.5, fraction_pos_test=0.49645390070921985)],
#  'CHEMBL2219274': [FSMolTaskSampleEvalResults(size=141, acc=0.6028368794326241, balanced_acc=0.6044685990338164, f1=0.6266666666666667, prec=0.5802469135802469, recall=0.6811594202898551, roc_auc=0.6754227053140097, avg_precision=0.6877102851814195, kappa=0.20818291215403129, task_name='CHEMBL2219274', seed=0, num_train=16, num_test=141, fraction_pos_train=0.5, fraction_pos_test=0.48936170212765956)],
#  'CHEMBL2219283': [FSMolTaskSampleEvalResults(size=141, acc=0.5035460992907801, balanced_acc=0.476060606060606, f1=0.07894736842105263, prec=0.3, recall=0.045454545454545456, roc_auc=0.5283838383838384, avg_precision=0.475640613258694, kappa=-0.050446998722860625, task_name='CHEMBL2219283', seed=0, num_train=16, num_test=141, fraction_pos_train=0.4375, fraction_pos_test=0.46808510638297873)],
#  'CHEMBL2219208': [FSMolTaskSampleEvalResults(size=141, acc=0.5035460992907801, balanced_acc=0.5079669221460266, f1=0.5333333333333333, prec=0.4819277108433735, recall=0.5970149253731343, roc_auc=0.522892295280355, avg_precision=0.5002508375487154, kappa=0.01575588352612678, task_name='CHEMBL2219208', seed=0, num_train=16, num_test=141, fraction_pos_train=0.5, fraction_pos_test=0.475177304964539)],
#  'CHEMBL2219286': [FSMolTaskSampleEvalResults(size=141, acc=0.6028368794326241, balanced_acc=0.6083937198067633, f1=0.6818181818181818, prec=0.5607476635514018, recall=0.8695652173913043, roc_auc=0.6467391304347825, avg_precision=0.5980956047971403, kappa=0.21432835820895513, task_name='CHEMBL2219286', seed=0, num_train=16, num_test=141, fraction_pos_train=0.5, fraction_pos_test=0.48936170212765956)],
#  'CHEMBL2219297': [FSMolTaskSampleEvalResults(size=141, acc=0.5319148936170213, balanced_acc=0.5300524405002016, f1=0.5, prec=0.5076923076923077, recall=0.4925373134328358, roc_auc=0.5792658329971763, avg_precision=0.5536900486516988, kappa=0.060189860634215275, task_name='CHEMBL2219297', seed=0, num_train=16, num_test=141, fraction_pos_train=0.5, fraction_pos_test=0.475177304964539)],
#  'CHEMBL2219305': [FSMolTaskSampleEvalResults(size=141, acc=0.5106382978723404, balanced_acc=0.5163174858984689, f1=0.5714285714285714, prec=0.4946236559139785, recall=0.6764705882352942, roc_auc=0.6059629331184528, avg_precision=0.6475240140226277, kappa=0.03222918531781549, task_name='CHEMBL2219305', seed=0, num_train=16, num_test=141, fraction_pos_train=0.5, fraction_pos_test=0.48226950354609927)],
#  'CHEMBL2219202': [FSMolTaskSampleEvalResults(size=141, acc=0.5035460992907801, balanced_acc=0.5030181086519114, f1=0.4615384615384615, prec=0.5, recall=0.42857142857142855, roc_auc=0.5440643863179075, avg_precision=0.5282900860079034, kappa=0.0060422960725075026, task_name='CHEMBL2219202', seed=0, num_train=16, num_test=141, fraction_pos_train=0.5, fraction_pos_test=0.49645390070921985)],
#  'CHEMBL2219308': [FSMolTaskSampleEvalResults(size=141, acc=0.5390070921985816, balanced_acc=0.5405432595573441, f1=0.6198830409356725, prec=0.5247524752475248, recall=0.7571428571428571, roc_auc=0.5233400402414488, avg_precision=0.535760835294175, kappa=0.08083441981747075, task_name='CHEMBL2219308', seed=0, num_train=16, num_test=141, fraction_pos_train=0.5, fraction_pos_test=0.49645390070921985)],
#  'CHEMBL2219335': [FSMolTaskSampleEvalResults(size=141, acc=0.5319148936170213, balanced_acc=0.527228721258572, f1=0.467741935483871, prec=0.5087719298245614, recall=0.43283582089552236, roc_auc=0.5606091165792657, avg_precision=0.5489750361237643, kappa=0.054844606946983565, task_name='CHEMBL2219335', seed=0, num_train=16, num_test=141, fraction_pos_train=0.5, fraction_pos_test=0.475177304964539)],
#  'CHEMBL2219340': [FSMolTaskSampleEvalResults(size=141, acc=0.6312056737588653, balanced_acc=0.6295289855072463, f1=0.5937500000000001, prec=0.6440677966101694, recall=0.5507246376811594, roc_auc=0.6133252818035426, avg_precision=0.5950007555466553, kappa=0.25984251968503935, task_name='CHEMBL2219340', seed=0, num_train=16, num_test=141, fraction_pos_train=0.5, fraction_pos_test=0.48936170212765956)],
#  'CHEMBL2219334': [FSMolTaskSampleEvalResults(size=141, acc=0.475177304964539, balanced_acc=0.4800564061240935, f1=0.5316455696202531, prec=0.4666666666666667, recall=0.6176470588235294, roc_auc=0.4998992747784045, avg_precision=0.49480443855214085, kappa=-0.03945008965929464, task_name='CHEMBL2219334', seed=0, num_train=16, num_test=141, fraction_pos_train=0.5, fraction_pos_test=0.48226950354609927)],
#  'CHEMBL2219352': [FSMolTaskSampleEvalResults(size=141, acc=0.49645390070921985, balanced_acc=0.49858984689766317, f1=0.5170068027210883, prec=0.4810126582278481, recall=0.5588235294117647, roc_auc=0.5111804995970992, avg_precision=0.5185173516107245, kappa=-0.002804768105779676, task_name='CHEMBL2219352', seed=0, num_train=16, num_test=141, fraction_pos_train=0.5, fraction_pos_test=0.48226950354609927)],
#  'CHEMBL2219355': [FSMolTaskSampleEvalResults(size=141, acc=0.48936170212765956, balanced_acc=0.49335748792270534, f1=0.5662650602409639, prec=0.4845360824742268, recall=0.6811594202898551, roc_auc=0.5035225442834138, avg_precision=0.5243976621681904, kappa=-0.013173652694610682, task_name='CHEMBL2219355', seed=0, num_train=16, num_test=141, fraction_pos_train=0.5, fraction_pos_test=0.48936170212765956)],
#  'CHEMBL2219358': [FSMolTaskSampleEvalResults(size=141, acc=0.48226950354609927, balanced_acc=0.4837022132796781, f1=0.5680473372781065, prec=0.48484848484848486, recall=0.6857142857142857, roc_auc=0.5108651911468813, avg_precision=0.5181514745006816, kappa=-0.03250075233222982, task_name='CHEMBL2219358', seed=0, num_train=16, num_test=141, fraction_pos_train=0.5, fraction_pos_test=0.49645390070921985)],
#  'CHEMBL2219359': [FSMolTaskSampleEvalResults(size=141, acc=0.574468085106383, balanced_acc=0.5776522791448164, f1=0.5890410958904109, prec=0.5443037974683544, recall=0.6417910447761194, roc_auc=0.5849132714804357, avg_precision=0.559263062591173, kappa=0.15400000000000003, task_name='CHEMBL2219359', seed=0, num_train=16, num_test=141, fraction_pos_train=0.5, fraction_pos_test=0.475177304964539)],
#  'CHEMBL2219363': [FSMolTaskSampleEvalResults(size=141, acc=0.5177304964539007, balanced_acc=0.5164989939637827, f1=0.4137931034482759, prec=0.5217391304347826, recall=0.34285714285714286, roc_auc=0.521830985915493, avg_precision=0.5205196097054143, kappa=0.03307785397337626, task_name='CHEMBL2219363', seed=0, num_train=16, num_test=141, fraction_pos_train=0.5, fraction_pos_test=0.49645390070921985)],
#  'CHEMBL2219252': [FSMolTaskSampleEvalResults(size=141, acc=0.5035460992907801, balanced_acc=0.5057344064386318, f1=0.6195652173913043, prec=0.5, recall=0.8142857142857143, roc_auc=0.4948692152917505, avg_precision=0.49579213492975094, kappa=0.011418269230769273, task_name='CHEMBL2219252', seed=0, num_train=16, num_test=141, fraction_pos_train=0.5, fraction_pos_test=0.49645390070921985)],
#  'CHEMBL2219366': [FSMolTaskSampleEvalResults(size=141, acc=0.5390070921985816, balanced_acc=0.5405432595573441, f1=0.6198830409356725, prec=0.5247524752475248, recall=0.7571428571428571, roc_auc=0.5875251509054327, avg_precision=0.5564128960543243, kappa=0.08083441981747075, task_name='CHEMBL2219366', seed=0, num_train=16, num_test=141, fraction_pos_train=0.5, fraction_pos_test=0.49645390070921985)],
#  'CHEMBL2219375': [FSMolTaskSampleEvalResults(size=141, acc=0.5886524822695035, balanced_acc=0.5884661835748792, f1=0.5797101449275363, prec=0.5797101449275363, recall=0.5797101449275363, roc_auc=0.6090982286634461, avg_precision=0.6099790389732561, kappa=0.17693236714975835, task_name='CHEMBL2219375', seed=0, num_train=16, num_test=141, fraction_pos_train=0.5, fraction_pos_test=0.48936170212765956)],
#  'CHEMBL2219399': [FSMolTaskSampleEvalResults(size=141, acc=0.48226950354609927, balanced_acc=0.4624242424242424, f1=0.21505376344086025, prec=0.37037037037037035, recall=0.15151515151515152, roc_auc=0.41131313131313135, avg_precision=0.42568187146705905, kappa=-0.07791391768771594, task_name='CHEMBL2219399', seed=0, num_train=16, num_test=141, fraction_pos_train=0.4375, fraction_pos_test=0.46808510638297873)],
#  'CHEMBL2219407': [FSMolTaskSampleEvalResults(size=141, acc=0.5390070921985816, balanced_acc=0.541044776119403, f1=0.5454545454545455, prec=0.5131578947368421, recall=0.582089552238806, roc_auc=0.5462888261395724, avg_precision=0.5005500547372304, kappa=0.08157129972943189, task_name='CHEMBL2219407', seed=0, num_train=16, num_test=141, fraction_pos_train=0.5, fraction_pos_test=0.475177304964539)],
#  'CHEMBL2219211': [FSMolTaskSampleEvalResults(size=141, acc=0.524822695035461, balanced_acc=0.5335414987912973, f1=0.6127167630057804, prec=0.5047619047619047, recall=0.7794117647058824, roc_auc=0.5038275584206285, avg_precision=0.48878374810408143, kappa=0.06585582913082177, task_name='CHEMBL2219211', seed=0, num_train=16, num_test=141, fraction_pos_train=0.5, fraction_pos_test=0.48226950354609927)],
#  'CHEMBL3214944': [FSMolTaskSampleEvalResults(size=562, acc=0.5693950177935944, balanced_acc=0.5698961499493415, f1=0.6218750000000001, prec=0.5527777777777778, recall=0.7107142857142857, roc_auc=0.5709219858156028, avg_precision=0.5325414954990327, kappa=0.13965080971659916, task_name='CHEMBL3214944', seed=0, num_train=16, num_test=562, fraction_pos_train=0.5, fraction_pos_test=0.498220640569395)],
#  'CHEMBL3431932': [FSMolTaskSampleEvalResults(size=443, acc=0.708803611738149, balanced_acc=0.7089193265663853, f1=0.7225806451612903, prec=0.6885245901639344, recall=0.7601809954751131, roc_auc=0.7478496596143656, avg_precision=0.7371213738039513, kappa=0.417740735835023, task_name='CHEMBL3431932', seed=0, num_train=16, num_test=443, fraction_pos_train=0.5, fraction_pos_test=0.49887133182844245)],
#  'CHEMBL2219389': [FSMolTaskSampleEvalResults(size=141, acc=0.5673758865248227, balanced_acc=0.5683098591549296, f1=0.6163522012578616, prec=0.550561797752809, recall=0.7, roc_auc=0.6326961770623742, avg_precision=0.5947834293235221, kappa=0.13635907219600363, task_name='CHEMBL2219389', seed=0, num_train=16, num_test=141, fraction_pos_train=0.5, fraction_pos_test=0.49645390070921985)],
#  'CHEMBL3431930': [FSMolTaskSampleEvalResults(size=458, acc=0.8187772925764192, balanced_acc=0.8187772925764192, f1=0.8143176733780759, prec=0.8348623853211009, recall=0.7947598253275109, roc_auc=0.8487156995480636, avg_precision=0.8764249743010547, kappa=0.6375545851528384, task_name='CHEMBL3431930', seed=0, num_train=16, num_test=458, fraction_pos_train=0.5, fraction_pos_test=0.5)],
#  'CHEMBL3705334': [FSMolTaskSampleEvalResults(size=127, acc=0.6456692913385826, balanced_acc=0.6463293650793651, f1=0.6715328467153284, prec=0.6216216216216216, recall=0.7301587301587301, roc_auc=0.7414434523809523, avg_precision=0.7387411369583635, kappa=0.2922600619195046, task_name='CHEMBL3705334', seed=0, num_train=16, num_test=127, fraction_pos_train=0.5, fraction_pos_test=0.49606299212598426)],
#  'CHEMBL3431933': [FSMolTaskSampleEvalResults(size=460, acc=0.5673913043478261, balanced_acc=0.567391304347826, f1=0.5227817745803357, prec=0.5828877005347594, recall=0.47391304347826085, roc_auc=0.5734782608695652, avg_precision=0.5914453279695229, kappa=0.13478260869565217, task_name='CHEMBL3431933', seed=0, num_train=16, num_test=460, fraction_pos_train=0.5, fraction_pos_test=0.5)],
#  'CHEMBL2219408': [FSMolTaskSampleEvalResults(size=141, acc=0.475177304964539, balanced_acc=0.4539393939393939, f1=0.17777777777777776, prec=0.3333333333333333, recall=0.12121212121212122, roc_auc=0.5356565656565656, avg_precision=0.5098220323758035, kappa=-0.0957781978575929, task_name='CHEMBL2219408', seed=0, num_train=16, num_test=141, fraction_pos_train=0.5, fraction_pos_test=0.46808510638297873)],
#  'CHEMBL3706128': [FSMolTaskSampleEvalResults(size=201, acc=0.746268656716418, balanced_acc=0.6960743801652892, f1=0.5853658536585366, prec=0.8372093023255814, recall=0.45, roc_auc=0.7142045454545455, avg_precision=0.6815888748269201, kappa=0.42548898727792417, task_name='CHEMBL3706128', seed=0, num_train=16, num_test=201, fraction_pos_train=0.375, fraction_pos_test=0.39800995024875624)],
#  'CHEMBL3705476': [FSMolTaskSampleEvalResults(size=648, acc=0.5740740740740741, balanced_acc=0.5744986901643249, f1=0.625, prec=0.5569007263922519, recall=0.7120743034055728, roc_auc=0.5976661109788045, avg_precision=0.56311730292536, kappa=0.14886974729929092, task_name='CHEMBL3705476', seed=0, num_train=16, num_test=648, fraction_pos_train=0.5, fraction_pos_test=0.4984567901234568)],
#  'CHEMBL3706356': [FSMolTaskSampleEvalResults(size=277, acc=0.6823104693140795, balanced_acc=0.6817850067771869, f1=0.6271186440677967, prec=0.7551020408163265, recall=0.5362318840579711, roc_auc=0.7724950474403086, avg_precision=0.7374663838334194, kappa=0.36394948335246846, task_name='CHEMBL3706356', seed=0, num_train=16, num_test=277, fraction_pos_train=0.5, fraction_pos_test=0.4981949458483754)],
#  'CHEMBL3707557': [FSMolTaskSampleEvalResults(size=124, acc=0.7661290322580645, balanced_acc=0.7661290322580645, f1=0.7563025210084033, prec=0.7894736842105263, recall=0.7258064516129032, roc_auc=0.8143860561914672, avg_precision=0.7426374012123078, kappa=0.532258064516129, task_name='CHEMBL3707557', seed=0, num_train=16, num_test=124, fraction_pos_train=0.5, fraction_pos_test=0.5)],
#  'CHEMBL2219404': [FSMolTaskSampleEvalResults(size=141, acc=0.5602836879432624, balanced_acc=0.5479023799919323, f1=0.392156862745098, prec=0.5714285714285714, recall=0.29850746268656714, roc_auc=0.5665590964098427, avg_precision=0.5779599809457923, kappa=0.09801898472967396, task_name='CHEMBL2219404', seed=0, num_train=16, num_test=141, fraction_pos_train=0.5, fraction_pos_test=0.475177304964539)],
#  'CHEMBL3707738': [FSMolTaskSampleEvalResults(size=130, acc=0.5, balanced_acc=0.5040246212121212, f1=0.6012269938650306, prec=0.494949494949495, recall=0.765625, roc_auc=0.4591619318181818, avg_precision=0.4691144704194287, kappa=0.007983094623151055, task_name='CHEMBL3707738', seed=0, num_train=16, num_test=130, fraction_pos_train=0.5, fraction_pos_test=0.49230769230769234)],
#  'CHEMBL3707783': [FSMolTaskSampleEvalResults(size=146, acc=0.8356164383561644, balanced_acc=0.8356164383561644, f1=0.8518518518518519, prec=0.7752808988764045, recall=0.9452054794520548, roc_auc=0.910958904109589, avg_precision=0.8855202964079794, kappa=0.6712328767123288, task_name='CHEMBL3707783', seed=0, num_train=16, num_test=146, fraction_pos_train=0.5, fraction_pos_test=0.5)],
#  'CHEMBL3887295': [FSMolTaskSampleEvalResults(size=223, acc=0.6547085201793722, balanced_acc=0.6550434362934363, f1=0.6778242677824267, prec=0.6328125, recall=0.7297297297297297, roc_auc=0.7217261904761902, avg_precision=0.6959508444073285, kappa=0.30987500502391385, task_name='CHEMBL3887295', seed=0, num_train=16, num_test=223, fraction_pos_train=0.5, fraction_pos_test=0.4977578475336323)],
#  'CHEMBL3887334': [FSMolTaskSampleEvalResults(size=210, acc=0.6476190476190476, balanced_acc=0.6476190476190475, f1=0.6636363636363636, prec=0.6347826086956522, recall=0.6952380952380952, roc_auc=0.6741043083900227, avg_precision=0.6421980189141274, kappa=0.2952380952380952, task_name='CHEMBL3887334', seed=0, num_train=16, num_test=210, fraction_pos_train=0.5, fraction_pos_test=0.5)],
#  'CHEMBL3887333': [FSMolTaskSampleEvalResults(size=490, acc=0.7816326530612245, balanced_acc=0.7816326530612245, f1=0.7458432304038005, prec=0.8920454545454546, recall=0.6408163265306123, roc_auc=0.8660641399416911, avg_precision=0.8889607050167537, kappa=0.563265306122449, task_name='CHEMBL3887333', seed=0, num_train=16, num_test=490, fraction_pos_train=0.5, fraction_pos_test=0.5)],
#  'CHEMBL3887759': [FSMolTaskSampleEvalResults(size=431, acc=0.617169373549884, balanced_acc=0.6172265288544359, f1=0.6258503401360545, prec=0.6106194690265486, recall=0.641860465116279, roc_auc=0.6227067183462531, avg_precision=0.6179691109210635, kappa=0.23442529416197477, task_name='CHEMBL3887759', seed=0, num_train=16, num_test=431, fraction_pos_train=0.5, fraction_pos_test=0.4988399071925754)],
#  'CHEMBL3888181': [FSMolTaskSampleEvalResults(size=203, acc=0.5123152709359606, balanced_acc=0.5119394292370414, f1=0.4705882352941177, prec=0.5116279069767442, recall=0.43564356435643564, roc_auc=0.5221801591923898, avg_precision=0.5532467429516028, kappa=0.02389625528194661, task_name='CHEMBL3888181', seed=0, num_train=16, num_test=203, fraction_pos_train=0.5, fraction_pos_test=0.4975369458128079)],
#  'CHEMBL3888461': [FSMolTaskSampleEvalResults(size=157, acc=0.6305732484076433, balanced_acc=0.6299902629016553, f1=0.5915492957746479, prec=0.65625, recall=0.5384615384615384, roc_auc=0.6623661148977604, avg_precision=0.6276637500083837, kappa=0.2602761982128351, task_name='CHEMBL3888461', seed=0, num_train=16, num_test=157, fraction_pos_train=0.5, fraction_pos_test=0.4968152866242038)],
#  'CHEMBL4005586': [FSMolTaskSampleEvalResults(size=232, acc=0.5732758620689655, balanced_acc=0.5753623188405798, f1=0.6550522648083624, prec=0.5465116279069767, recall=0.8173913043478261, roc_auc=0.6135265700483092, avg_precision=0.600666803251695, kappa=0.15008880994671403, task_name='CHEMBL4005586', seed=0, num_train=16, num_test=232, fraction_pos_train=0.5, fraction_pos_test=0.4956896551724138)],
#  'CHEMBL4133035': [FSMolTaskSampleEvalResults(size=182, acc=0.6593406593406593, balanced_acc=0.6593406593406594, f1=0.630952380952381, prec=0.6883116883116883, recall=0.5824175824175825, roc_auc=0.7057722497282937, avg_precision=0.6595820591100088, kappa=0.31868131868131866, task_name='CHEMBL4133035', seed=0, num_train=16, num_test=182, fraction_pos_train=0.5, fraction_pos_test=0.5)],
#  'CHEMBL3705469': [FSMolTaskSampleEvalResults(size=139, acc=0.5611510791366906, balanced_acc=0.5625258799171843, f1=0.6303030303030303, prec=0.5416666666666666, recall=0.7536231884057971, roc_auc=0.601863354037267, avg_precision=0.5862919528878687, kappa=0.12470321048828326, task_name='CHEMBL3705469', seed=0, num_train=16, num_test=139, fraction_pos_train=0.5, fraction_pos_test=0.49640287769784175)],
#  'CHEMBL641707': [FSMolTaskSampleEvalResults(size=148, acc=0.7567567567567568, balanced_acc=0.6795871076469349, f1=0.55, prec=0.6666666666666666, recall=0.46808510638297873, roc_auc=0.8052454181588372, avg_precision=0.6357154527541266, kappa=0.39024948500801104, task_name='CHEMBL641707', seed=0, num_train=16, num_test=148, fraction_pos_train=0.3125, fraction_pos_test=0.31756756756756754)],
#  'CHEMBL657032': [FSMolTaskSampleEvalResults(size=139, acc=0.697841726618705, balanced_acc=0.69648033126294, f1=0.625, prec=0.813953488372093, recall=0.5072463768115942, roc_auc=0.7695652173913045, avg_precision=0.7773391216866953, kappa=0.39402117500518996, task_name='CHEMBL657032', seed=0, num_train=16, num_test=139, fraction_pos_train=0.5, fraction_pos_test=0.49640287769784175)],
#  'CHEMBL663407': [FSMolTaskSampleEvalResults(size=124, acc=0.6532258064516129, balanced_acc=0.6532258064516129, f1=0.6993006993006994, prec=0.6172839506172839, recall=0.8064516129032258, roc_auc=0.6741675338189386, avg_precision=0.6370405465510832, kappa=0.30645161290322576, task_name='CHEMBL663407', seed=0, num_train=16, num_test=124, fraction_pos_train=0.5, fraction_pos_test=0.5)],
#  'CHEMBL819742': [FSMolTaskSampleEvalResults(size=142, acc=0.7746478873239436, balanced_acc=0.7746478873239437, f1=0.7142857142857142, prec=0.975609756097561, recall=0.5633802816901409, roc_auc=0.9225352112676056, avg_precision=0.9191530062883899, kappa=0.5492957746478873, task_name='CHEMBL819742', seed=0, num_train=16, num_test=142, fraction_pos_train=0.5, fraction_pos_test=0.5)],
#  'CHEMBL915809': [FSMolTaskSampleEvalResults(size=139, acc=0.7050359712230215, balanced_acc=0.6902286902286903, f1=0.594059405940594, prec=0.8333333333333334, recall=0.46153846153846156, roc_auc=0.8233887733887734, avg_precision=0.812838552429026, kappa=0.39106742173309117, task_name='CHEMBL915809', seed=0, num_train=16, num_test=139, fraction_pos_train=0.4375, fraction_pos_test=0.4676258992805755)],
#  'CHEMBL924949': [FSMolTaskSampleEvalResults(size=126, acc=0.8333333333333334, balanced_acc=0.8319052419354839, f1=0.8141592920353982, prec=0.9019607843137255, recall=0.7419354838709677, roc_auc=0.8785282258064516, avg_precision=0.9046469117426565, kappa=0.66565579984837, task_name='CHEMBL924949', seed=0, num_train=16, num_test=126, fraction_pos_train=0.5, fraction_pos_test=0.49206349206349204)],
#  'CHEMBL2354305': [FSMolTaskSampleEvalResults(size=158, acc=0.5569620253164557, balanced_acc=0.5569620253164557, f1=0.6698113207547169, prec=0.5338345864661654, recall=0.8987341772151899, roc_auc=0.6861881108796668, avg_precision=0.7078403823557539, kappa=0.11392405063291144, task_name='CHEMBL2354305', seed=0, num_train=16, num_test=158, fraction_pos_train=0.5, fraction_pos_test=0.5)]}

# %%
results['CHEMBL1066254']
# Out:
# [FSMolTaskSampleEvalResults(size=125, acc=0.688, balanced_acc=0.6918545081967213, f1=0.7272727272727272, prec=0.6341463414634146, recall=0.8524590163934426, roc_auc=0.7792008196721312, avg_precision=0.7488349885286565, kappa=0.38063778427137596, task_name='CHEMBL1066254', seed=0, num_train=16, num_test=125, fraction_pos_train=0.5, fraction_pos_test=0.488)]
